# %%
(246+127)%256
# Out:
# 117

# %%
for b in ['100', '101']:
    print(int(b, 2))
# Out:
# 4
# 5

# %%
exp = '011000111'
print(int(exp, 2))
# Out:
# 199

# %%
exp = '010111111'
print(int(exp, 2))
# Out:
# 191
